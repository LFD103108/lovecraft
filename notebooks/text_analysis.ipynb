# %%
# Libraries
import numpy as np                      # imports the Numpy library for numerical tools
import pandas as pd                     # imports the Pandas library for data manipulation and analysis
from matplotlib import pyplot as plt    # imports the Pyplot module from the Matplotlib library for plotting

# %%
df_texts = pd.read_csv('data/gold/texts.csv', index_col=0)
df_texts.head()
# Out:
#                                                                    text  \
# mountains_of_madness  AT THE MOUNTAINS OF MADNESS\n\nI\n\nI am force...
# nyarlathotep          NYARLATHOTEP\n\nNyarlathotep...the crawling ch...
# moon_bog              THE MOON BOG\n\nSomewhere, to what remote and ...
# book                  THE BOOK\n\nMy memories are very confused. The...
# other_gods            THE OTHER GODS\n\nBut now they have betaken th...
#
#                       sentence_count  word_count  character_count  \
# mountains_of_madness            1396       40413           245865
# nyarlathotep                      55        1130             6718
# moon_bog                         109        3413            18595
# book                              47        1146             6398
# other_gods                        81        1897            10325
#
#                            numerical_representation  \
# mountains_of_madness        [65 84 32 ... 33 34 10]
# nyarlathotep          [ 78  89  65 ... 112  46  10]
# moon_bog              [ 84  72  69 ... 121  46  10]
# book                        [84 72 69 ... 46 46 10]
# other_gods            [ 84  72  69 ... 115  46  10]
#
#                                                       fourier_transform
# mountains_of_madness  [ 2.29433700e+07    +0.j         -3.02154135e+...
# nyarlathotep          [ 6.23696000e+05-1.13686838e-12j  5.18190572e+...
# moon_bog              [ 1.70811300e+06+6.43467502e-11j -1.05182255e+...
# book                  [ 5.87197000e+05-2.88764568e-11j  3.42919162e+...
# other_gods            [ 9.41199000e+05   +0.j         -7.20406775e+0...

# %%
cthulhu_num = df_texts['numerical_representation']['cthulhu']  
cthulhu_fourier = df_texts['fourier_transform']['cthulhu']

# %%
cthulhu_num
# Out:
# '[ 84  72  69 ... 101  46  10]'

# %%
len(cthulhu_num)
# Out:
# 29

# %%
#plt.plot(cthulhu_num)
#plt.title('Call of Cthulhu - numerical representation')
#plt.show()

plt.plot(  cthulhu_fourier  )
#plt.xscale('log')
#plt.yscale('symlog')
plt.title('Call of Cthulhu - Fourier transform')
# Out:
# Text(0.5, 1.0, 'Call of Cthulhu - Fourier transform')

# %%
plt.plot( (1,1) )
