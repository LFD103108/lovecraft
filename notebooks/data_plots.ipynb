# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib as plt 
from pathlib import Path
import os

def find_project_root(start=Path.cwd(), marker='data'): # defines a function to find the project root directory by looking for a specific marker (default is 'data')
    current = start
    while current != current.parent:
        if (current / marker).exists():
            return current
        current = current.parent
    raise FileNotFoundError("Project root not found")

PROJECT_ROOT = find_project_root()

os.chdir(PROJECT_ROOT)

df_works = pd.read_csv('data/bronze/dataframes/lovecraft_works.csv')

# %%
df_works
# Out:
#                                               title            magazine  \
# 0                                     the_alchemist  the_united_amateur
# 1               a_reminiscence_of_dr_samuel_johnson  the_united_amateur
# 2                             the_beast_in_the_cave         the_vagrant
# 3                          beyond_the_wall_of_sleep          pine_cones
# 4                                    the_white_ship  the_united_amateur
# ..                                              ...                 ...
# 94                                           bothon     amazing_stories
# 95                 the_dreamquest_of_unknown_kadath  the_arkham_sampler
# 96  sweet_ermengarde_or_the_heart_of_a_country_girl              mirage
# 97                                     ex_oblivione  magazine_of_horror
# 98                                  satans_servants  magazine_of_horror
#
#     year_published      collaboration         form
# 0             1916                NaN  short_story
# 1             1917                NaN  short_story
# 2             1918                NaN  short_story
# 3             1919                NaN  short_story
# 4             1919                NaN  short_story
# ..             ...                ...          ...
# 94            1946  whitehead_henry_s  short_story
# 95            1948                NaN      novella
# 96            1965                NaN  short_story
# 97            1968                NaN  short_story
# 98            1969       bloch_robert  short_story
#
# [99 rows x 5 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Most magazines published

# %%
df_works.plot()
